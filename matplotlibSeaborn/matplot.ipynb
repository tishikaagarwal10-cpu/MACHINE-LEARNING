# %%
# %pip install matplotlib seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

titan = pd.read_csv("/Users/tishikaagarwal/Desktop/Machine Learning/Data/Titanic-Dataset.csv")
mpg = pd.read_csv("/Users/tishikaagarwal/Desktop/Machine Learning/Data/mpg.csv")

print(titan.shape, mpg.shape)
# Out:
# (891, 12) (398, 9)

# %%
titan.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
#THE MATPLOTLIB SKELETON

plt.figure(figsize=(7,4))
sns.histplot(data=titan, x='Fare', y='Age')
plt.title('fare')
plt.grid()
plt.show()

# %% [markdown]
# UNIVARIATE - ONE COLUMN AT A TIME

# %%
# distribution of fare

plt.figure(figsize=(7,4))
sns.histplot(data=titan, x='Fare', bins=20)
plt.title('fare')
plt.grid()
plt.show()

# %%
# distribution of age

plt.figure(figsize=(7,4))
sns.histplot(data=titan, x='Age', bins=20)
plt.title('Age Distrubution')
plt.show()

# %%
#countplot - how many in each category
#how many survived and how many died

plt.figure(figsize=(7,4))
sns.countplot(data=titan, x='Survived')
plt.title('Survived')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=mpg, x='mpg', bins=25)
plt.title('mpg Data')
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(data=titan, x='Survived' , y='Fare')
plt.title('TITANIC DATA')
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(data=titan, x='Age' , y='Fare' , hue="Pclass")
plt.title('TITANIC DATA')
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.boxplot(data=titan, x='Age' , y='Fare' , hue="Sex`gn")
plt.title('TITANIC DATA')
plt.show()

# %%
# %pip install scikit-learn
# Out:
# ERROR: Could not find a version that satisfies the requirement scikit-learn (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# ERROR: No matching distribution found for scikit-learn
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x10be2a510>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pip/
# ...
#   Using cached pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.2 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.
